# %%
import pandas as pd

# %%
df_origin = pd.read_csv("./100-25-artificial-capsnet.csv")
df_to = pd.read_csv("./200-25-artificial-FCNN.csv")
df_origin = df_origin.append(df_to)

# %%
df_origin.to_csv("./capsnet_metaadd.csv")
# Out:
#     Unnamed: 0 Dataset DetectionMethod  acc_slide_chunk  acc_std_default  \
# 0            0    elec           ADWIN         0.739517         0.791931
# 1            1    elec             DDM         0.739517         0.821791
# 2            2    elec            EDDM         0.739517         0.826801
# 3            3    elec          HDDM_A         0.739517         0.830663
# 4            4    elec          HDDM_W         0.739517         0.827441
# ..         ...     ...             ...              ...              ...
# 4            0   SEAa0            HANG         0.843800         0.835900
# 5            1    HYPi            HANG         0.816300         0.863900
# 6            2    AGRa            HANG         0.703000         0.628900
# 7            3    RTGn            HANG         0.645600         0.669000
# 8            4    RBFi            HANG         0.693100         0.710300
#
#     ndd_std_default      eddr  TargetDDI
# 0                46  0.548773        0.8
# ...
