# %%
import pandas as pd

# %%
df = pd.read_csv("./200-25-artificial-FCNN.csv")
df
# Out:
#     Unnamed: 0 Dataset DetectionMethod  acc_slide_chunk  acc_std_default  \
# 0            0    elec         Capsnet         0.739517         0.727180
# 1            1    elec            HANG         0.739517         0.748080
# 2            2    elec           ADWIN         0.739517         0.791931
# 3            3    elec             DDM         0.739517         0.821791
# 4            4    elec            EDDM         0.739517         0.826801
# ..         ...     ...             ...              ...              ...
# 67          35    RBFi             DDM         0.693100         0.715000
# 68          36    RBFi            EDDM         0.693100         0.678300
# 69          37    RBFi          HDDM_A         0.693100         0.715000
# 70          38    RBFi          HDDM_W         0.693100         0.698900
# 71          39    RBFi     PageHinkley         0.693100         0.715200
#
#     ndd_std_default      eddr        f1      time
# ...

# %%
real = ["elec","weat","spam","airl"]
for row in df.iterrows():
    if not row[1][2] == ("HANG") and row[1][1] in real :
        print("    \\texttt{%s} & %s & %s & %s\\\\" % (row[1][2],str(row[1][4])[0:6],str(row[1][-3])[0:6],str(row[1][-2])[0:6]))
# Out:
#     \texttt{Capsnet} & 0.7271 & 0.5592 & 0.7954\\
#     \texttt{ADWIN} & 0.7919 & 0.5487 & 0.8253\\
#     \texttt{DDM} & 0.8217 & 0.5531 & 0.8469\\
#     \texttt{EDDM} & 0.8268 & 0.5572 & 0.8526\\
#     \texttt{HDDM_A} & 0.8306 & 0.5532 & 0.8521\\
#     \texttt{HDDM_W} & 0.8274 & 0.5548 & 0.8505\\
#     \texttt{PageHinkley} & 0.7823 & 0.5474 & 0.8184\\
#     \texttt{Capsnet} & 0.6921 & 0.6345 & 0.7677\\
#     \texttt{ADWIN} & 0.6952 & 0.6358 & 0.7556\\
#     \texttt{DDM} & 0.7033 & 0.6500 & 0.7793\\
#     \texttt{EDDM} & 0.7373 & 0.6786 & 0.8119\\
#     \texttt{HDDM_A} & 0.7239 & 0.6658 & 0.7911\\
#     \texttt{HDDM_W} & 0.7266 & 0.6703 & 0.7975\\
#     \texttt{PageHinkley} & 0.6962 & 0.6288 & 0.7569\\
#     \texttt{Capsnet} & 0.9126 & 0.7433 & 0.9430\\
#     \texttt{ADWIN} & 0.9242 & 0.7433 & 0.9500\\
#     \texttt{DDM} & 0.9197 & 0.7430 & 0.9464\\
#     \texttt{EDDM} & 0.9343 & 0.7432 & 0.9558\\
#     \texttt{HDDM_A} & 0.9214 & 0.7433 & 0.9478\\
# ...
